# %% [markdown]
# ## Task 1 - Download the dataset: Dataset

# %%
# Downloaded

# %% [markdown]
# ## Task 2 - Load the dataset

# %%
import pandas as pd

# %%
df = pd.read_csv('House Price India.csv')

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
df.shape
# Out:
# (14620, 23)

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %%
df.dtypes
# Out:
# id                                         int64
# Date                                       int64
# number of bedrooms                         int64
# number of bathrooms                      float64
# living area                                int64
# lot area                                   int64
# number of floors                         float64
# waterfront present                         int64
# number of views                            int64
# condition of the house                     int64
# grade of the house                         int64
# Area of the house(excluding basement)      int64
# Area of the basement                       int64
# Built Year                                 int64
# Renovation Year                            int64
# Postal Code                                int64
# Lattitude                                float64
# Longitude                                float64
# living_area_renov                          int64
# ...

# %% [markdown]
# ## Task 3 - Perform the Below Visualizations.
# ### Univariate Analysis
# ### Bi - Variate Analysis
# ### Multivariate Analysis

# %% [markdown]
# ### Univariate analysis ---

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %%
sns.distplot(df['living area'])
# Out:
# C:\Users\prate\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='living area', ylabel='Density'>

# %%
sns.displot(df['living_area_renov'])

# %%
df['condition of the house'].value_counts()
# Out:
# 3    9350
# 4    3874
# 5    1278
# 2     100
# 1      18
# Name: condition of the house, dtype: int64

# %%
sns.barplot(x=df['condition of the house'].value_counts().index,y=df['condition of the house'].value_counts())
# Out:
# <AxesSubplot:ylabel='condition of the house'>

# %%
df['Number of schools nearby'].value_counts()
# Out:
# 3    4973
# 2    4853
# 1    4794
# Name: Number of schools nearby, dtype: int64

# %%
plt.pie(df['Number of schools nearby'].value_counts(),[0.1,0,0],labels=[3,2,1],autopct='%1.1f%%',shadow=True)
plt.title('Number of schools nearby')
plt.show()

# %%
sns.displot(df['Built Year'])

# %% [markdown]
# ### Bi - Variate Analysis ---

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
sns.lineplot(x=df['number of bedrooms'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='number of bedrooms', ylabel='Price'>

# %%
sns.scatterplot(x=df['number of views'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='number of views', ylabel='Price'>

# %%
sns.lineplot(x=df['living area'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='living area', ylabel='Price'>

# %%
sns.lineplot(x=df['Distance from the airport'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Distance from the airport', ylabel='Price'>

# %%
sns.lineplot(x=df['Number of schools nearby'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='Number of schools nearby', ylabel='Price'>

# %%
sns.lineplot(x=df['condition of the house'],y=df['Price'])
# Out:
# <AxesSubplot:xlabel='condition of the house', ylabel='Price'>

# %% [markdown]
# ### Multivariate analysis ---

# %%
df.head()
# Out:
#            id   Date  number of bedrooms  number of bathrooms  living area  \
# 0  6762810145  42491                   5                 2.50         3650
# 1  6762810635  42491                   4                 2.50         2920
# 2  6762810998  42491                   5                 2.75         2910
# 3  6762812605  42491                   4                 2.50         3310
# 4  6762812919  42491                   3                 2.00         2710
#
#    lot area  number of floors  waterfront present  number of views  \
# 0      9050               2.0                   0                4
# 1      4000               1.5                   0                0
# 2      9480               1.5                   0                0
# 3     42998               2.0                   0                0
# 4      4500               1.5                   0                0
#
#    condition of the house  ...  Built Year  Renovation Year  Postal Code  \
# ...

# %%
sns.pairplot(data=df, vars=['number of bedrooms', 'number of bathrooms', 'living area', 'lot area', 'Price'])

# %%
sns.pairplot(data=df, vars=['living_area_renov', 'lot_area_renov', 'Price'])

# %%
sns.pairplot(data=df, vars=['number of floors', 'number of views', 'Number of schools nearby', 'Price'])

# %%
sns.heatmap(df[['number of bedrooms','number of bathrooms','number of floors','number of views','Price']].corr(),annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Task 4 - Perform descriptive statistics on the dataset.

# %%
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...

# %% [markdown]
# ## Task 5 - Handle the Missing values.

# %%
df.isnull().any()
# Out:
# id                                       False
# Date                                     False
# number of bedrooms                       False
# number of bathrooms                      False
# living area                              False
# lot area                                 False
# number of floors                         False
# waterfront present                       False
# number of views                          False
# condition of the house                   False
# grade of the house                       False
# Area of the house(excluding basement)    False
# Area of the basement                     False
# Built Year                               False
# Renovation Year                          False
# Postal Code                              False
# Lattitude                                False
# Longitude                                False
# living_area_renov                        False
# lot_area_renov                           False
# ...

# %%
df.isnull().sum()
# Out:
# id                                       0
# Date                                     0
# number of bedrooms                       0
# number of bathrooms                      0
# living area                              0
# lot area                                 0
# number of floors                         0
# waterfront present                       0
# number of views                          0
# condition of the house                   0
# grade of the house                       0
# Area of the house(excluding basement)    0
# Area of the basement                     0
# Built Year                               0
# Renovation Year                          0
# Postal Code                              0
# Lattitude                                0
# Longitude                                0
# living_area_renov                        0
# lot_area_renov                           0
# Number of schools nearby                 0
# Distance from the airport                0
# ...

# %%
# There are no missing values in the given dataset. If there's any missing value in any of the parameter we can replace those nulll values by median of the data (for that parameter).
